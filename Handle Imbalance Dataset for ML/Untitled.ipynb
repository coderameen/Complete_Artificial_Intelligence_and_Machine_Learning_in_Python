# %% [markdown]
# ### Imbalance Dataset

# %% [markdown]
# ##### A dataset with an unequal class distribution

# %%
import pandas as pd
import numpy as np

# %%
#load dataset
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#Separrating the legit and fraudulant transactions
legit = df[df.Class == 0]
fraud = df[df.Class == 1]
print(legit.shape, fraud.shape)
# Out:
# (284315, 31) (492, 31)

# %%
#idea: create a new sample in which it contains similar distribution of legit and fraudulent transaction
legit_sample = legit.sample(n=492)
legit_sample.shape
# Out:
# (492, 31)

# %%
#concatinate the two dataframes(ie. legit_sample,fraud)
new_dataset = pd.concat([legit_sample,fraud],axis=0)
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 275718  166689.0  1.336538 -1.454110 -1.942915  0.300286  0.019802  0.035894
# 226402  144611.0  1.935829 -0.356121 -0.323273  0.182275 -0.696961 -0.809285
# 24761    33372.0 -0.972620 -0.319224  3.232150 -1.222722 -1.461216  0.034129
# 83020    59656.0  1.254225 -0.056855  0.934108  0.649653 -0.552550  0.200456
# 97361    66185.0 -9.271350 -0.652237 -2.738126 -2.794451 -4.104597  0.387410
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 275718  0.453765 -0.104133  0.465866  ... -0.052989 -0.963032 -0.069265
# 226402 -0.335033 -0.173119  1.338771  ... -0.139595 -0.240772  0.317610
# 24761  -0.592142  0.250034  0.128368  ... -0.460043 -0.519620 -0.164993
# 83020  -0.553218  0.045405  0.771958  ... -0.134312 -0.102492 -0.083958
# 97361   4.736889 -2.011125  5.818632  ... -2.010345  0.407846 -0.393845
#
# ...

# %%
new_dataset['Class']
