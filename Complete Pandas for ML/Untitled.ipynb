# %% [markdown]
# # Pandas
# #### Pandas are used for data Analysis and its a powerful tool to handle ordered and unordered datasets

# %%
#To import pandas... 'pip install pandas'
import pandas as pd

# %%
#How to import csv file (dataset)
data = pd.read_csv("Wrestler.csv")
data
# Out:
#     s.n.                 Name  Wins  Loss  Draw  Gender
# 0    1.0          Roman Reign  43.0   3.0   7.0    Male
# 1    2.0         Brock Lesnar  89.0  12.0  12.0    Male
# 2    3.0           Undertaker  75.0   9.0   8.0    Male
# 3    4.0             Goldberg  43.0   5.0   3.0    Male
# 4    5.0         Seth Rollins  34.0  10.0   3.0    Male
# 5    6.0         Dean Ambrose  31.0  10.0   5.0    Male
# 6    7.0         Sawn Michael  67.0  11.0  13.0    Male
# 7    8.0                Rusev  23.0   7.0   3.0    Male
# 8    9.0             The Rock  78.0  13.0  18.0    Male
# 9   10.0             Triple H  71.0  18.0   9.0    Male
# 10  11.0          Randy Orton  65.0   9.0   1.0    Male
# 11  12.0           A.J. Style  34.0   7.0   3.0    Male
# 12  13.0           Hulk Hogan  37.0  12.0   8.0    Male
# 13  14.0                 Edge  78.0  19.0  11.0    Male
# 14  15.0           Kurt Angle  80.0  20.0  11.0    Male
# 15  16.0                 Kane  66.0  12.0   8.0    Male
# ...

# %%
data.head()#default it read 5 records
# Out:
#    s.n.          Name  Wins  Loss  Draw Gender
# 0   1.0   Roman Reign  43.0   3.0   7.0   Male
# 1   2.0  Brock Lesnar  89.0  12.0  12.0   Male
# 2   3.0    Undertaker  75.0   9.0   8.0   Male
# 3   4.0      Goldberg  43.0   5.0   3.0   Male
# 4   5.0  Seth Rollins  34.0  10.0   3.0   Male

# %%
data.head(8)
# Out:
#    s.n.          Name  Wins  Loss  Draw Gender
# 0   1.0   Roman Reign  43.0   3.0   7.0   Male
# 1   2.0  Brock Lesnar  89.0  12.0  12.0   Male
# 2   3.0    Undertaker  75.0   9.0   8.0   Male
# 3   4.0      Goldberg  43.0   5.0   3.0   Male
# 4   5.0  Seth Rollins  34.0  10.0   3.0   Male
# 5   6.0  Dean Ambrose  31.0  10.0   5.0   Male
# 6   7.0  Sawn Michael  67.0  11.0  13.0   Male
# 7   8.0         Rusev  23.0   7.0   3.0   Male

# %%
data.tail()
# Out:
#     s.n.         Name  Wins  Loss  Draw  Gender
# 45  46.0        Asuka  23.0   2.0   2.0  Female
# 46  47.0     Carmella  17.0   7.0   1.0  Female
# 47  48.0       AJ Lee  57.0  11.0   9.0  Female
# 48  49.0      Nia Jax  15.0   1.0   0.0  Female
# 49  50.0  Nikki Cross  14.0   7.0   3.0  Female

# %%
data.tail(8)
# Out:
#     s.n.         Name  Wins  Loss  Draw  Gender
# 42  43.0  Becky Lynch  61.0  17.0   3.0  Female
# 43  44.0  Sasha Banks  57.0  11.0   4.0  Female
# 44  45.0  Alexa Bliss  44.0   4.0   6.0  Female
# 45  46.0        Asuka  23.0   2.0   2.0  Female
# 46  47.0     Carmella  17.0   7.0   1.0  Female
# 47  48.0       AJ Lee  57.0  11.0   9.0  Female
# 48  49.0      Nia Jax  15.0   1.0   0.0  Female
# 49  50.0  Nikki Cross  14.0   7.0   3.0  Female

# %%
data.head()
# Out:
#    s.n.          Name  Wins  Loss  Draw Gender
# 0   1.0   Roman Reign  43.0   3.0   7.0   Male
# 1   2.0  Brock Lesnar  89.0  12.0  12.0   Male
# 2   3.0    Undertaker  75.0   9.0   8.0   Male
# 3   4.0      Goldberg  43.0   5.0   3.0   Male
# 4   5.0  Seth Rollins  34.0  10.0   3.0   Male

# %%
#How to remove a column from dataset
data.drop(columns=['s.n.'],inplace=True)

# %%
data.head()
# Out:
#            Name  Wins  Loss  Draw Gender
# 0   Roman Reign  43.0   3.0   7.0   Male
# 1  Brock Lesnar  89.0  12.0  12.0   Male
# 2    Undertaker  75.0   9.0   8.0   Male
# 3      Goldberg  43.0   5.0   3.0   Male
# 4  Seth Rollins  34.0  10.0   3.0   Male

# %%
#Read headers names
data.columns
# Out:
# Index(['Name', 'Wins', 'Loss', 'Draw', 'Gender'], dtype='object')

# %%
#Read all perticular columns
data[['Name','Wins']].head()
# Out:
#            Name  Wins
# 0   Roman Reign  43.0
# 1  Brock Lesnar  89.0
# 2    Undertaker  75.0
# 3      Goldberg  43.0
# 4  Seth Rollins  34.0

# %%
#read particular data
data.loc[data['Name']=='John cena']
# Out:
#          Name  Wins  Loss  Draw Gender
# 37  John cena  93.0  11.0   5.0   Male

# %%
#read particular rows
data.iloc[36:41]
# Out:
#                    Name  Wins  Loss  Draw Gender
# 36          Rob Van Dam  44.0   7.0   5.0   Male
# 37            John cena  93.0  11.0   5.0   Male
# 38            Samae Joe  54.0   6.0   1.0   Male
# 39       The Great Kali  23.0   6.0   3.0   Male
# 40  Modern day Maharaja  11.0   3.0   3.0   Male

# %%
sel_data =data.iloc[39:41]

# %%
sel_data
# Out:
#                    Name  Wins  Loss  Draw Gender
# 39       The Great Kali  23.0   6.0   3.0   Male
# 40  Modern day Maharaja  11.0   3.0   3.0   Male

# %%
#How to save our dataset
sel_data.to_csv("Indian_Wrestler.csv",index=False)

# %%
sel_data
# Out:
#                    Name  Wins  Loss  Draw Gender
# 39       The Great Kali  23.0   6.0   3.0   Male
# 40  Modern day Maharaja  11.0   3.0   3.0   Male

# %%
data.head()
# Out:
#            Name  Wins  Loss  Draw Gender
# 0   Roman Reign  43.0   3.0   7.0   Male
# 1  Brock Lesnar  89.0  12.0  12.0   Male
# 2    Undertaker  75.0   9.0   8.0   Male
# 3      Goldberg  43.0   5.0   3.0   Male
# 4  Seth Rollins  34.0  10.0   3.0   Male

# %%
data.iloc[0,0]#iloc[row,column]
# Out:
# 'Roman Reign'

# %%
data.iloc[2,0]
# Out:
# 'Undertaker'

# %%
data.head()
# Out:
#            Name  Wins  Loss  Draw  Total Matches
# 0   Roman Reign  43.0   3.0   7.0           53.0
# 1  Brock Lesnar  89.0  12.0  12.0          113.0
# 2    Undertaker  75.0   9.0   8.0           92.0
# 3      Goldberg  43.0   5.0   3.0           51.0
# 4  Seth Rollins  34.0  10.0   3.0           47.0

# %%
#sorting our data in dataset
data.sort_values('Wins').head()#Ascending to descending sorting
# Out:
#                    Name  Wins  Loss  Draw  Total Matches
# 40  Modern day Maharaja  11.0   3.0   3.0           17.0
# 49          Nikki Cross  14.0   7.0   3.0           24.0
# 48              Nia Jax  15.0   1.0   0.0           16.0
# 46             Carmella  17.0   7.0   1.0           25.0
# 26       Brawn Strowman  18.0   2.0   2.0           22.0

# %%
data.sort_values('Wins',ascending=False).head()
# Out:
#             Name  Wins  Loss  Draw  Total Matches
# 37     John cena  93.0  11.0   5.0          109.0
# 1   Brock Lesnar  89.0  12.0  12.0          113.0
# 32      Booker T  88.0  21.0  11.0          120.0
# 16       CM punk  88.0  13.0   6.0          107.0
# 22      Big show  87.0  11.0   2.0          100.0

# %%
data.head()
# Out:
#            Name  Wins  Loss  Draw  Total Matches
# 0   Roman Reign  43.0   3.0   7.0           53.0
# 1  Brock Lesnar  89.0  12.0  12.0          113.0
# 2    Undertaker  75.0   9.0   8.0           92.0
# 3      Goldberg  43.0   5.0   3.0           51.0
# 4  Seth Rollins  34.0  10.0   3.0           47.0

# %%
#Adding new columns in existing dataset
data['Total Matches'] = data['Wins']+data['Loss']+data['Draw']

# %%
#To delete columns
# data.drop(columns=['Gender'],inplace=True)
# data.head()

# %%
data.head()
# Out:
#            Name  Wins  Loss  Draw  Total Matches
# 0   Roman Reign  43.0   3.0   7.0           53.0
# 1  Brock Lesnar  89.0  12.0  12.0          113.0
# 2    Undertaker  75.0   9.0   8.0           92.0
# 3      Goldberg  43.0   5.0   3.0           51.0
# 4  Seth Rollins  34.0  10.0   3.0           47.0

# %%
#To handle NAN(Not a Number)
import numpy as np
data.loc[50] = (['Ameen',100,0,0,np.nan])

# %%
data.tail()
# Out:
#            Name   Wins  Loss  Draw  Total Matches
# 46     Carmella   17.0   7.0   1.0           25.0
# 47       AJ Lee   57.0  11.0   9.0           77.0
# 48      Nia Jax   15.0   1.0   0.0           16.0
# 49  Nikki Cross   14.0   7.0   3.0           24.0
# 50        Ameen  100.0   0.0   0.0            NaN

# %%
data = data.dropna(axis=0)#0=>row 1=>columns

# %%
data.tail()
# Out:
#            Name  Wins  Loss  Draw  Total Matches
# 45        Asuka  23.0   2.0   2.0           27.0
# 46     Carmella  17.0   7.0   1.0           25.0
# 47       AJ Lee  57.0  11.0   9.0           77.0
# 48      Nia Jax  15.0   1.0   0.0           16.0
# 49  Nikki Cross  14.0   7.0   3.0           24.0

# %%
#To create our own dataset
data = pd.DataFrame([
    ['Ameen',27,'Bhadravathi'],
    ['Prajwal',26,'Shimoga'],
    ['Sanaan',26,'Hydrabad']],
    index=[0,1,2],
    columns=['Name','Age','Place'])

# %%
data
# Out:
#       Name  Age        Place
# 0    Ameen   27  Bhadravathi
# 1  Prajwal   26      Shimoga
# 2   Sanaan   26     Hydrabad

# %%
#save
data.to_csv("My_own_dataset.csv",index=False)

# %%
#loading my own dataset
df = pd.read_csv("My_own_dataset.csv")
df
# Out:
#       Name  Age        Place
# 0    Ameen   27  Bhadravathi
# 1  Prajwal   26      Shimoga
# 2   Sanaan   26     Hydrabad

# %%
data.describe()
# Out:
#              Age
# count   3.000000
# mean   26.333333
# std     0.577350
# min    26.000000
# 25%    26.000000
# 50%    26.000000
# 75%    26.500000
# max    27.000000

# %%
data
