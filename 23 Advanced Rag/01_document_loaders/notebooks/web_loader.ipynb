# %%
from langchain_community.document_loaders import WebBaseLoader
from pprint import pp
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
# create the loader

url_1 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pypdfloader"
url_2 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pdfminer"
url_3 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pdfplumber"

loader = WebBaseLoader(web_paths=[url_1, url_2, url_3])

# %%
# load the document

documents = loader.load()

# %%
len(documents)
# Out:
# 3

# %%
print(documents[2].page_content)
# Out:
# PDFPlumber - Docs by LangChainSkip to main contentDocs by LangChain home pageLangChain + LangGraphSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationPDFPlumberLangChainLangGraphDeep AgentsIntegrationsLearnReferenceContributePythonLangChain integrationsAll providersPopular ProvidersOpenAIAnthropic (Claude)GoogleAWS (Amazon)Hugging FaceMicrosoftOllamaGroqIntegrations by componentChat modelsTools and toolkitsMiddlewareRetrieversText splittersEmbedding modelsVector storesDocument loadersKey-value storesOn this pageOverviewIntegration detailsLoader featuresSetupCredentialsInstallationInitializationLoadLazy loadAPI referencePDFPlumberCopy pageCopy pageLike PyMuPDF, the output Documents contain detailed metadata about the PDF and its pages, and returns one document per page.
# ​Overview
# ​Integration details
# ClassPackageLocalSerializableJS supportPDFPlumberLoaderlangchain-community✅❌❌
# ​Loader features
# SourceDocument Lazy LoadingNative Async SupportPDFPlumberLoader✅❌
# ​Setup
# ​Credentials
# No credentials are needed to use this loader.
# To enable automated tracing of your model calls, set your LangSmith API key:
# Copyos.environ["LANGSMITH_API_KEY"] = getpass.getpass("Enter your LangSmith API key: ")
# os.environ["LANGSMITH_TRACING"] = "true"
#
# ​Installation
# Install langchain-community.
# Copypip install -qU langchain-community pdfplumber
#
# ​Initialization
# Now we can instantiate our model object and load documents:
# Copyfrom langchain_community.document_loaders import PDFPlumberLoader
#
# loader = PDFPlumberLoader("./example_data/layout-parser-paper.pdf")
#
# ​Load
# Copydocs = loader.load()
# docs[0]
#
# CopyDocument(metadata={'source': './example_data/layout-parser-paper.pdf', 'file_path': './example_data/layout-parser-paper.pdf', 'page': 0, 'total_pages': 16, 'Author': '', 'CreationDate': 'D:20210622012710Z', 'Creator': 'LaTeX with hyperref', 'Keywords': '', 'ModDate': 'D:20210622012710Z', 'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2', 'Producer': 'pdfTeX-1.40.21', 'Subject': '', 'Title': '', 'Trapped': 'False'}, page_content='LayoutParser: A Unified Toolkit for Deep\nLearning Based Document Image Analysis\nZejiang Shen1 ((cid:0)), Ruochen Zhang2, Melissa Dell3, Benjamin Charles Germain\nLee4, Jacob Carlson3, and Weining Li5\n1 Allen Institute for AI\[email protected]\n2 Brown University\nruochen [email protected]\n3 Harvard University\n{melissadell,jacob carlson}@fas.harvard.edu\n4 University of Washington\[email protected]\n5 University of Waterloo\[email protected]\nAbstract. Recentadvancesindocumentimageanalysis(DIA)havebeen\nprimarily driven by the application of neural networks. Ideally, research\noutcomescouldbeeasilydeployedinproductionandextendedforfurther\ninvestigation. However, various factors like loosely organized codebases\nand sophisticated model configurations complicate the easy reuse of im-\nportantinnovationsbyawideaudience.Thoughtherehavebeenon-going\nefforts to improve reusability and simplify deep learning (DL) model\ndevelopmentindisciplineslikenaturallanguageprocessingandcomputer\nvision, none of them are optimized for challenges in the domain of DIA.\nThis represents a major gap in the existing toolkit, as DIA is central to\nacademicresearchacross awiderangeof disciplinesinthesocialsciences\nand humanities. This paper introduces LayoutParser, an open-source\nlibrary for streamlining the usage of DL in DIA research and applica-\ntions. The core LayoutParser library comes with a set of simple and\nintuitiveinterfacesforapplyingandcustomizingDLmodelsforlayoutde-\ntection,characterrecognition,andmanyotherdocumentprocessingtasks.\nTo promote extensibility, LayoutParser also incorporates a community\nplatform for sharing both pre-trained models and full document digiti-\nzation pipelines. We demonstrate that LayoutParser is helpful for both\nlightweight and large-scale digitization pipelines in real-word use cases.\nThe library is publicly available at https://layout-parser.github.io.\nKeywords: DocumentImageAnalysis·DeepLearning·LayoutAnalysis\n· Character Recognition · Open Source library · Toolkit.\n1 Introduction\nDeep Learning(DL)-based approaches are the state-of-the-art for a wide range of\ndocumentimageanalysis(DIA)tasksincludingdocumentimageclassification[11,\n1202\nnuJ\n12\n]VC.sc[\n2v84351.3012:viXra\n')
#
# Copyprint(docs[0].metadata)
#
# Copy{'source': './example_data/layout-parser-paper.pdf', 'file_path': './example_data/layout-parser-paper.pdf', 'page': 0, 'total_pages': 16, 'Author': '', 'CreationDate': 'D:20210622012710Z', 'Creator': 'LaTeX with hyperref', 'Keywords': '', 'ModDate': 'D:20210622012710Z', 'PTEX.Fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2', 'Producer': 'pdfTeX-1.40.21', 'Subject': '', 'Title': '', 'Trapped': 'False'}
#
# ​Lazy load
# Copypage = []
# for doc in loader.lazy_load():
#     page.append(doc)
#     if len(page) >= 10:
#         # do some paged operation, e.g.
#         # index.upsert(page)
#
#         page = []
#
#
# ​API reference
# For detailed documentation of all PDFPlumberLoader features and configurations head to the API reference: python.langchain.com/api_reference/community/document_loaders/langchain_community.document_loaders.pdf.PDFPlumberLoader.html
#
# Edit this page on GitHub or file an issue.
# Connect these docs to Claude, VSCode, and more via MCP for real-time answers.Was this page helpful?YesNo⌘IDocs by LangChain home pagegithubxlinkedinyoutubeResourcesForumChangelogLangChain AcademyTrust CenterCompanyAboutCareersBloggithubxlinkedinyoutubePowered by

# %%
pp(documents[2].metadata)
# Out:
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/pdfplumber',
#  'title': 'PDFPlumber - Docs by LangChain',
#  'language': 'en'}

# %% [markdown]
# ### Recursive Loader

# %%
from langchain_community.document_loaders import RecursiveUrlLoader

# %%
# create the loader

base_url = "https://docs.langchain.com/oss/python/integrations/document_loaders"

loader = RecursiveUrlLoader(url=base_url,
                            max_depth=2)

# %%
# load the documents

documents = loader.load()
# Out:
# d:\rag-document-loaders\.venv\Lib\site-packages\langchain_community\document_loaders\recursive_url_loader.py:44: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(raw_html, "html.parser")

# %%
# number of documents

len(documents)
# Out:
# 222

# %%
documents[0].page_content[:500]
# Out:
# '<!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify-assets/_next/static/media/bb3ef058b751a6ad-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/mintlify-assets/_next/static/media/c4b700dcb2187787-s.p.woff2" as="font" c'

# %%
documents[0].metadata
# Out:
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Document loaders - Docs by LangChain',
#  'language': 'en'}

# %%
# lazy load

documents_lazy_load = loader.lazy_load()

# %%
documents_lazy_load
# Out:
# <generator object RecursiveUrlLoader._get_child_links_recursive at 0x000001FD616EE3E0>

# %%
counter = 0

for document in documents_lazy_load:
    # stop condition
    if counter == 20:
        break
    
    # incerement the counter
    counter += 1
    
    # print metadata and page content
    print(document.page_content[0:300])
    pp(document.metadata)
# Out:
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Document loaders - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/twitter',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Twitter - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/source_code',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Source Code - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/azure_ai_data',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Azure AI Data - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/providers/ollama',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Ollama - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/pull_md',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Page Not Found',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/llmsherpa',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'LLM Sherpa - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/lakefs',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'lakeFS - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/tomarkdown',
#  'content_type': 'text/html; charset=utf-8',
#  'title': '2Markdown - Docs by LangChain',
#  'language': 'en'}
# d:\rag-document-loaders\.venv\Lib\site-packages\langchain_community\document_loaders\recursive_url_loader.py:44: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(raw_html, "html.parser")
# <?xml version="1.0" encoding="UTF-8"?>
# <urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9" xmlns:news="http://www.google.com/schemas/sitemap-news/0.9" xmlns:xhtml="http://www.w3.org/1999/xhtml" xmlns:image="http://www.google.com/schemas/sitemap-image/1.1" xmlns:video="http://www.google.com/s
# {'source': 'https://docs.langchain.com/sitemap.xml', 'content_type': 'text/xml'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/mhtml',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'mhtml - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/microsoft_excel',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Microsoft Excel - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/aws_s3_directory',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'AWS S3 Directory - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/microsoft_sharepoint',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Microsoft SharePoint - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/yuque',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Yuque - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/firecrawl',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'FireCrawl - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/psychic',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Psychic - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_cloud_storage_file',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google Cloud Storage File - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/google_el_carro',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Google El Carro for Oracle Workloads - Docs by LangChain',
#  'language': 'en'}
# <!DOCTYPE html><html lang="en" class="__variable_47c970 __variable_3bbdad dark" data-banner-state="visible" data-page-mode="none"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, viewport-fit=cover"/><link rel="preload" href="/mintlify
# {'source': 'https://docs.langchain.com/oss/python/integrations/document_loaders/mastodon',
#  'content_type': 'text/html; charset=utf-8',
#  'title': 'Mastodon - Docs by LangChain',
#  'language': 'en'}

# %%
#Work
from langchain_community.document_loaders import WebBaseLoader

# %%
# url_1 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pypdfloader"
# url_2 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pdfminer"
# url_3 = "https://docs.langchain.com/oss/python/integrations/document_loaders/pdfplumber"




url = "https://medium.com/@asnirudhadak25/vpc-virtual-private-cloud-8ffe0a3ee092vp"
loader = WebBaseLoader(url)
documents = loader.load()
documents[0].page_content
# Out:
# 'MediumSitemapOpen in appSign upSign inMedium LogoGet appWriteSearchSign upSign inPAGE NOT FOUND404Out of nothing, something.You can find (just about) anything on Medium — apparently even a page that doesn’t exist. Maybe these stories will take you somewhere new?HomeParticipation Is RealityJohn GormanJun 22, 2026·9 min readMember-onlyParticipation Is RealityJohn GormanJun 22, 2026·9 min readMember-onlyThe Beautiful AccidentMark AndrewsJun 30, 2026·7 min readThe Beautiful AccidentMark AndrewsJun 30, 2026·7 min readI Didn’t Have a ‘Chinaman’s Chance’Paul Yee\xa0in The Narrative ArcJun 29, 2026·8 min readMember-onlyI Didn’t Have a ‘Chinaman’s Chance’Paul Yee\xa0in The Narrative ArcJun 29, 2026·8 min readMember-onlyWhy reading “The Decameron” is as useful as everNikolaus CorrellJun 30, 2026·9 min readMember-onlyWhy reading “The Decameron” is as useful as everNikolaus CorrellJun 30, 2026·9 min readMember-only\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'

# %%
# !pip install webloader
# Out:
# Collecting webloader
#   Downloading webloader-0.1.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting bs4 (from webloader)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: pydantic in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from webloader) (2.12.4)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from bs4->webloader) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from beautifulsoup4->bs4->webloader) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from beautifulsoup4->bs4->webloader) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from pydantic->webloader) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from pydantic->webloader) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages (from pydantic->webloader) (0.4.2)
# Downloading webloader-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4, webloader
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [webloader]
# Successfully installed bs4-0.0.2 webloader-0.1.0
#
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
