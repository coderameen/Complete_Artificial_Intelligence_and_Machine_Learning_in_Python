# %%
from langchain_community.document_loaders.json_loader import JSONLoader
from pathlib import Path
from pprint import pp

# %%
# create the path for json file

file_path = Path("../knowledge-source/apparels.json")

file_path.exists()
# Out:
# True

# %%
def metadata_func(record: dict, metadata: dict) -> dict:
    metadata["product_name"] = record["productName"]
    metadata["category"] = record["category"]
    metadata["price"] = record["price"]
    # delete seq num
    del metadata["seq_num"]
    return metadata

# %%
# form the loader

loader = JSONLoader(file_path=file_path.as_posix(),
                    jq_schema=".products[]",
                    content_key="Description",
                    metadata_func=metadata_func)

# %%
# documents

documents = loader.load()

# %%
for doc in documents:
    print(doc.page_content, end="\n\n")
# Out:
# Oversize-fit coat made of a viscose blend fabric. Notch lapel collar and long sleeves with buttoned cuffs.
#
# Trench coat made of technical fabric with a velvety finish. Notch lapel collar and long sleeves.
#
# Parka made of technical fabric, padded on inside. High neck with a hood and long sleeves with elasticated cuffs.
#
# The first Vibrant Leather for le benjamin with its fruity hint of pineapple that gives it modernity, accompanied by cedar notes, adding a woody touch of rejuvenation.
#
# Multicoloured backpack. Soft construction. Featuring one main zip pocket and a medium-sized zip pocket on the inside.

# %%
documents[0].metadata
# Out:
# {'source': 'D:\\rag-document-loaders\\knowledge-source\\apparels.json',
#  'product_name': 'PINSTRIPE COAT',
#  'category': 'Men Cloths',
#  'price': 4900}

# %%
len(documents)
# Out:
# 5

# %%
from langchain_community.document_loaders.json_loader import JSONLoader

# %%
from pathlib import Path

# %%
file_path = Path("../knowledge-source/apparels.json")
file_path.exists()
# Out:
# True

# %%
def metadata_func(record: dict, metadata: dict) -> dict:
    metadata["product_name"] = record["productName"]
    metadata["category"] = record["category"]
    metadata["price"] = record["price"]
    # delete seq num
    del metadata["seq_num"]
    return metadata

loader = JSONLoader(file_path=file_path.as_posix(),
                    jq_schema=".products[]",
                    content_key="Description",
                    metadata_func=metadata_func)
documents = loaders.load()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 13
#       9 loader = JSONLoader(file_path=file_path.as_posix(),
#      10                     jq_schema=".products[]",
#      11                     content_key="Description",
#      12                     metadata_func=metadata_func)
# ---> 13 documents = loaders.load()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/langchain_core/document_loaders/base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/langchain_community/document_loaders/json_loader.py:147, in JSONLoader.lazy_load(self)
#     145                     index += 1
#     146 else:
# --> 147     for doc in self._parse(
#     148         self.file_path.read_text(encoding="utf-8-sig"), index
#     149     ):
#     150         yield doc
#     151         index += 1
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/langchain_community/document_loaders/json_loader.py:164, in JSONLoader._parse(self, content, index)
#     161     self._validate_content_key(data)
#     163 for i, sample in enumerate(data, index + 1):
# --> 164     text = self._get_text(sample=sample)
#     165     metadata = self._get_metadata(
#     166         sample=sample, source=str(self.file_path), seq_num=i
#     167     )
#     168     yield Document(page_content=text, metadata=metadata)
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/site-packages/langchain_community/document_loaders/json_loader.py:182, in JSONLoader._get_text(self, sample)
#     179     content = sample
#     181 if self._text_content and not isinstance(content, str) and content is not None:
# --> 182     raise ValueError(
#     183         f"Expected page_content is string, got {type(content)} instead. \
#     184             Set `text_content=False` if the desired input for \
#     185             `page_content` is not a string"
#     186     )
#     188 # In case the text is None, set it to an empty string
#     189 elif isinstance(content, str):
#
# ValueError: Expected page_content is string, got <class 'dict'> instead.                     Set `text_content=False` if the desired input for                     `page_content` is not a string

# %%
# !pip install jq
# Out:
# Collecting jq
#   Downloading jq-1.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.0 kB)
# Downloading jq-1.11.0-cp312-cp312-macosx_11_0_arm64.whl (422 kB)
# Installing collected packages: jq
# Successfully installed jq-1.11.0
#
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
