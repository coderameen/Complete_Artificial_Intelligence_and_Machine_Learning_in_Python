# %% [markdown]
# # PDF to Chroma Pipeline
#
# This notebook loads a PDF, splits it into chunks, stores the chunks in Chroma, and runs a retrieval query.

# %%
import os
from pathlib import Path

from dotenv import load_dotenv
from langchain_chroma import Chroma
from langchain_community.document_loaders import PyPDFLoader
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %% [markdown]
# ## 1. Prepare Paths and Configuration

# %%
project_root = Path.cwd()
if project_root.name == "notebooks":
    project_root = project_root.parent

project_root
# Out:
# WindowsPath('d:/rag-vector-stores')

# %%
env_path = project_root / ".env"
pdf_path = project_root / "documents" / "beyond-chatbots-ai-agents-next-real-shift.pdf"
persist_directory = project_root / "notebooks" / "chroma_langchain_db"
collection_name = "rag-pipeline"

print(f"PDF path: {pdf_path}")
print(f"Collection name: {collection_name}")
print(f"Persist directory: {persist_directory}")
# Out:
# PDF path: d:\rag-vector-stores\documents\beyond-chatbots-ai-agents-next-real-shift.pdf
# Collection name: rag-pipeline
# Persist directory: d:\rag-vector-stores\notebooks\chroma_langchain_db

# %%
load_dotenv(dotenv_path=env_path)

if not os.getenv("OPENAI_API_KEY"):
    raise ValueError("Please add your OPENAI_API_KEY to the .env file before running this notebook.")

print(f"Loaded environment from: {env_path}")
# Out:
# Loaded environment from: d:\rag-vector-stores\.env

# %%
# Reuse the same embedding model as the other notebooks in this repo.
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
print("Embedding model is ready.")
# Out:
# Embedding model is ready.

# %% [markdown]
# ## 2. Add Small Display Helpers

# %%
def preview_text(text, limit=120):
    """Return a short preview for cleaner notebook output."""
    if len(text) <= limit:
        return text
    return text[:limit] + "..."


def print_documents(title, docs):
    """Print retrieved documents using page metadata and a text preview."""
    print(title)
    for index, doc in enumerate(docs, start=1):
        print(f"{index}. page={doc.metadata.get('page')} | source={doc.metadata.get('source')}")
        print(f"   content={doc.page_content}")
    print()

# %% [markdown]
# ## 3. Load the PDF

# %%
loader = PyPDFLoader(str(pdf_path))

# %%
docs = loader.load()
print(f"Total pages loaded: {len(docs)}")
# Out:
# Total pages loaded: 6

# %%
docs[0].page_content
# Out:
# 'Page 1\n Beyond Chatbots: Why AI Agents Feel Like the\n Next Real Shift\nA practical long-form blog on planning, memory, tools, and retrieval in modern AI systems\nBy Editorial Desk\nThe moment AI stopped feeling like a demo\nFor a long time, the most common experience with AI felt theatrical. You typed a question, the model\nanswered in polished language, and for a moment it seemed almost magical. Then the illusion broke. Ask a\nfollow-up that required memory, factual grounding, or a small sequence of actions, and the system often fell\napart. It could sound confident without being connected to anything real. That gap between fluency and\nusefulness is exactly where AI agents enter the picture.\nAn AI agent is interesting not because it sounds human, but because it behaves like software with intent. It\ncan take a goal, figure out what it needs in order to make progress, and work through a sequence of steps\ninstead of improvising a single reply. In the simplest form, that might mean searching a few stored documents\nbefore answering. In a more advanced workflow, it might mean retrieving context, calling a tool, checking the\nresult, and only then producing a response. The big shift is that the system stops being just a speaker and\nstarts acting like a coordinator.\nThat matters because most useful work is not a one-turn conversation. Writing a project summary, answering\na support question, planning research, checking a policy, or preparing a technical response all require\ncontext. People do not solve those tasks by generating elegant paragraphs in a vacuum. They look things up,\ncompare evidence, and revise their approach based on what they find. When AI systems start following a\nsimilar pattern, they begin to feel less like isolated model calls and more like practical assistants that can\nparticipate in real workflows.\nThis is also why vector stores and retrieval have become such central topics in modern AI tutorials. Once you\naccept that an agent should gather context instead of guessing from memory alone, you need a mechanism to\nstore and retrieve that context efficiently. A document becomes chunks. Chunks become embeddings.\nEmbeddings live in a vector store. A question becomes a search query. Suddenly the architecture feels much\nmore tangible, and the answers often become much more trustworthy.\nWhat makes an agent different from a clever prompt\nThere is a useful distinction between a strong prompt and an actual agent workflow. A strong prompt can\nimprove output quality, impose structure, and guide tone. But it is still asking the model to do everything in one\npass. An agent workflow introduces external support. It gives the system a way to remember, retrieve,\ncalculate, inspect, and choose. That difference sounds subtle at first, but it changes the entire character of the\napplication.\nA prompt says, in effect, do your best with what you have right now. An agent says, first decide what you\nneed, then go get it. That second approach is more robust because it acknowledges the limitations of the'

# %%
print(f"First page preview: {preview_text(docs[0].page_content)}")
print(f"First page metadata: {docs[0].metadata}")
# Out:
# First page preview: Page 1
#  Beyond Chatbots: Why AI Agents Feel Like the
#  Next Real Shift
# A practical long-form blog on planning, memory, to...
# First page metadata: {'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-03-12T20:36:07+05:00', 'author': 'By Editorial Desk', 'keywords': '', 'moddate': '2026-03-12T20:36:07+05:00', 'subject': '(unspecified)', 'title': 'Beyond Chatbots: Why AI Agents Feel Like the Next Real Shift', 'trapped': '/False', 'source': 'd:\\rag-vector-stores\\documents\\beyond-chatbots-ai-agents-next-real-shift.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}

# %% [markdown]
# ## 4. Split the PDF into Chunks

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=300,
    chunk_overlap=50,
)

# %%
chunked_docs = text_splitter.split_documents(docs)
print(f"Total chunks created: {len(chunked_docs)}")
# Out:
# Total chunks created: 88

# %%
print(f"First chunk preview: {preview_text(chunked_docs[0].page_content)}")
print(f"First chunk metadata: {chunked_docs[0].metadata}")
# Out:
# First chunk preview: Page 1
#  Beyond Chatbots: Why AI Agents Feel Like the
#  Next Real Shift
# A practical long-form blog on planning, memory, to...
# First chunk metadata: {'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-03-12T20:36:07+05:00', 'author': 'By Editorial Desk', 'keywords': '', 'moddate': '2026-03-12T20:36:07+05:00', 'subject': '(unspecified)', 'title': 'Beyond Chatbots: Why AI Agents Feel Like the Next Real Shift', 'trapped': '/False', 'source': 'd:\\rag-vector-stores\\documents\\beyond-chatbots-ai-agents-next-real-shift.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}

# %% [markdown]
# ## 5. Store Chunks in Chroma

# %%
collection_name
# Out:
# 'rag-pipeline'

# %%
persist_directory
# Out:
# WindowsPath('d:/rag-vector-stores/notebooks/chroma_langchain_db')

# %%
vector_store = Chroma.from_documents(
    documents=chunked_docs,
    embedding=embeddings,
    collection_name=collection_name,
    persist_directory=str(persist_directory),
)

print(f"Stored {len(chunked_docs)} chunks in the '{collection_name}' collection.")
# Out:
# Stored 88 chunks in the 'rag-pipeline' collection.

# %% [markdown]
# ## 6. Retrieve Relevant Chunks

# %%
query = "How do AI agents use tools and memory?"
query
# Out:
# 'How do AI agents use tools and memory?'

# %%
results = vector_store.similarity_search(query, k=3)

print(f"Query: {query}\n")
print_documents("Retrieved chunks:", results)
# Out:
# Query: How do AI agents use tools and memory?
#
# Retrieved chunks:
# 1. page=2 | source=d:\rag-vector-stores\documents\beyond-chatbots-ai-agents-next-real-shift.pdf
#    content=reveals the reasoning surface of the system. The answer no longer feels like a black box. It feels like the
# product of a process that can be inspected.
# Why tools make agents actually useful
# If memory gives an agent context, tools give it reach. A model can describe a search, but a tool can perform
# 2. page=2 | source=d:\rag-vector-stores\documents\beyond-chatbots-ai-agents-next-real-shift.pdf
#    content=Page 3
# Memory is not just a feature, it is a design decision
# When people first hear that agents need memory, they sometimes imagine a giant transcript that the model
# carries forever. In practice, memory is much more selective than that. Good systems decide what should stay
# 3. page=0 | source=d:\rag-vector-stores\documents\beyond-chatbots-ai-agents-next-real-shift.pdf
#    content=An AI agent is interesting not because it sounds human, but because it behaves like software with intent. It
# can take a goal, figure out what it needs in order to make progress, and work through a sequence of steps

# %%
retrieved_docs = vector_store.similarity_search_with_score(query, k=2)

for doc, score in retrieved_docs:
    print(f"Score: {score:.4f}")
    print(f"Content preview: {doc.page_content}")
    print(f"page_no. {doc.metadata.get("page_label")}")
    print()
# Out:
# Score: 0.8494
# Content preview: reveals the reasoning surface of the system. The answer no longer feels like a black box. It feels like the
# product of a process that can be inspected.
# Why tools make agents actually useful
# If memory gives an agent context, tools give it reach. A model can describe a search, but a tool can perform
# page_no. 3
#
# Score: 0.8948
# Content preview: Page 3
# Memory is not just a feature, it is a design decision
# When people first hear that agents need memory, they sometimes imagine a giant transcript that the model
# carries forever. In practice, memory is much more selective than that. Good systems decide what should stay
# page_no. 3
